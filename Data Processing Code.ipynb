# %% [markdown]
# # Install and Import Statements

# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
client_id = "356131409c1141859412a3aec845851d"
client_secret = "af7d17d875f74c4ca08a3aff0daad72a"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
import pandas

# %% [markdown]
# # Functions

# %%
# Extract track URI from URL
def get_track_uri(track_url):
    uri = track_url[31:]
    return uri

# %%
# Get audio feature values for a given song
def extract_audio_features(track_uri):
    # List of features
    features = ['danceability', 'energy', 'loudness', 'acousticness', 'instrumentalness',
                'liveness','valence', 'tempo', 'duration_ms']
    audio_features = {}
    
    # Retrieve values from Spotify API
    result = sp.audio_features(track_uri)
    
    # Store feature values in a dictionary
    for feature in features:
        audio_features.update( {feature : result[0][feature]})
        
    return audio_features

# %%
# Add audio features for a given song into a DataFrame
def add_audio_features(track_name, track_uri, track_audio_features, df):
    audio_values = list(track_audio_features.values()) # Convert audio features to list format
    audio_values.insert(0, track_uri) # Insert URI into DataFrame
    audio_values.insert(0, track_name) # Insert track name into DataFrame
    df_length = len(df)
    df.loc[df_length] = audio_values

# %%
# Add audio features to an existing master DataFrame
def add_stats_to_existing_dataframe(df):
    for i in df.index:
        track_url = df.loc[i]["URL"]
        uri = get_track_uri(track_url)
        df.at[i, "URI"] = uri   # Add URI value to DataFrame
        track_audio_features = extract_audio_features(uri)
        audio_values = list(track_audio_features.values()) # Convert audio features to list format
        
        start_col = 8
        for index in range (0, len(audio_values)):
            df.iat[i, start_col] = audio_values[index]
            start_col += 1

# %% [markdown]
# # Creating DataFrame with All Song Stats

# %%
column_names = ["Track Name", "URI", "Danceability", "Energy", "Loudness", "Acousticness", "Instrumentalness", "Liveness","Valence", "Tempo", "Duration_Ms"]

# %%
# Importing all CSV files
france = pandas.read_csv("france.csv")
italy = pandas.read_csv("italy.csv")
portugal = pandas.read_csv("portugal.csv")
spain = pandas.read_csv("Spain.csv")
switzerland = pandas.read_csv("switzerland.csv")
taiwan = pandas.read_csv("taiwan.csv")
uk = pandas.read_csv("united-kingdom.csv")
usa = pandas.read_csv("united-states.csv")
vietnam = pandas.read_csv("vietnam.csv")

# %%
# Create a new DataFrame with only song attributes
all_song_data = pandas.DataFrame(columns = column_names)

# %%
# Adding France's songs to all_song_data DataFrame
for i in france.index:
    track_name = france.loc[i]["Track Name"]
    track_url = france.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Italy's songs to all_song_data DataFrame
for i in italy.index:
    track_name = italy.loc[i]["Track Name"]
    track_url = italy.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Portugal's songs to all_song_data DataFrame
for i in portugal.index:
    track_name = portugal.loc[i]["Track Name"]
    track_url = portugal.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Spain's songs to all_song_data DataFrame
for i in spain.index:
    track_name = spain.loc[i]["Track Name"]
    track_url = spain.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Switzerland's songs to all_song_data DataFrame
for i in switzerland.index:
    track_name = switzerland.loc[i]["Track Name"]
    track_url = switzerland.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Taiwan's songs to all_song_data DataFrame
for i in taiwan.index:
    track_name = taiwan.loc[i]["Track Name"]
    track_url = taiwan.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding United Kingdom's songs to all_song_data DataFrame
for i in uk.index:
    track_name = uk.loc[i]["Track Name"]
    track_url = uk.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding United States's songs to all_song_data DataFrame
for i in usa.index:
    track_name = usa.loc[i]["Track Name"]
    track_url = usa.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
# Adding Vietnam's songs to all_song_data DataFrame
for i in vietnam.index:
    track_name = vietnam.loc[i]["Track Name"]
    track_url = vietnam.loc[i]["URL"]
    uri = get_track_uri(track_url)
    track_audio_features = extract_audio_features(uri)
    add_audio_features(track_name, uri, track_audio_features, all_song_data)
    all_song_data = all_song_data.drop_duplicates()

# %%
all_song_data.head()
# Out:
#         Track Name                     URI  Danceability  Energy  Loudness  \
# 0   Ne reviens pas  4TnFANpjVwVKWzkxNzIyFH         0.932   0.778    -3.384
# 1          Moulaga  5BfCoUcWNXcpyJfjXRIeyC         0.710   0.699    -4.664
# 2     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku         0.825   0.593    -6.401
# 3  Blinding Lights  0sf12qNH5qcw8qpgymFOqD         0.513   0.796    -4.075
# 4          Popopop  18HNGxDOcshRU2Hdu8tMOM         0.833   0.652    -6.194
#
#    Acousticness Instrumentalness  Liveness  Valence    Tempo Duration_Ms
# 0       0.21200                0    0.1680    0.933  124.996      188613
# 1       0.32700         4.64e-06    0.0975    0.484  125.051      179868
# 2       0.68800         0.000161    0.1700    0.540   98.078      209755
# 3       0.00147         0.000209    0.0938    0.345  171.017      201573
# 4       0.04770         0.000138    0.1450    0.414  130.002      155632

# %%
# Exporting DataFrame to CSV
all_song_data.to_csv("all_song_stats.csv")

# %% [markdown]
# # Adding Song Stats to Existing DataFrames

# %% [markdown]
# ## France

# %%
# Adding new columns to France DataFrame for song attributes
france["URI"] = ""
france["Danceability"] = ""
france["Energy"] = ""
france["Loudness"] = ""
france["Acousticness"] = ""
france["Instrumentalness"] = ""
france["Liveness"] = ""
france["Valence"] = ""
france["Tempo"] = ""
france["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(france)

# %%
france.head()
# Out:
#         Track Name            Artist  Streams  \
# 0   Ne reviens pas            Gradur  3948207
# 1          Moulaga  Heuss L'enfoirÃ©  3035799
# 2     Dance Monkey       Tones And I  2282643
# 3  Blinding Lights        The Weeknd  1772905
# 4          Popopop             Gambi  1659801
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/4TnFANpjVwVKWzk...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/5BfCoUcWNXcpyJf...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/0sf12qNH5qcw8qp...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/18HNGxDOcshRU2H...   12/27/19   1/3/20
#
#    Region                     URI Danceability Energy Loudness Acousticness  \
# 0  France  4TnFANpjVwVKWzkxNzIyFH        0.932  0.778   -3.384        0.212
# 1  France  5BfCoUcWNXcpyJfjXRIeyC         0.71  0.699   -4.664        0.327
# ...

# %% [markdown]
# ## Italy

# %%
# Adding new columns to Italy DataFrame for song attributes
italy["URI"] = ""
italy["Danceability"] = ""
italy["Energy"] = ""
italy["Loudness"] = ""
italy["Acousticness"] = ""
italy["Instrumentalness"] = ""
italy["Liveness"] = ""
italy["Valence"] = ""
italy["Tempo"] = ""
italy["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(italy)

# %%
italy.head()
# Out:
#                                           Track Name       Artist  Streams  \
# 0                                  blun7 a swishland  tha Supreme  3084106
# 1                                            fuck 3x  tha Supreme  1957574
# 2                                       Dance Monkey  Tones And I  1943487
# 3       Ti volevo dedicare (feat. J-AX & Boomdabash)   Rocco Hunt  1605060
# 4  SUPREME - L'ego (feat. tha Supreme & Sfera Ebb...    Marracash  1602522
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/7HwvPmK74MBRDhC...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/5YxP1CkunbhUQVv...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/00GxbkrW4m1Tac5...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/020wG4EHTwBy5h2...   12/27/19   1/3/20
#
# ...

# %% [markdown]
# ## Portugal

# %%
# Adding new columns to Portugal DataFrame for song attributes
portugal["URI"] = ""
portugal["Danceability"] = ""
portugal["Energy"] = ""
portugal["Loudness"] = ""
portugal["Acousticness"] = ""
portugal["Instrumentalness"] = ""
portugal["Liveness"] = ""
portugal["Valence"] = ""
portugal["Tempo"] = ""
portugal["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(portugal)

# %%
portugal.head()
# Out:
#                   Track Name       Artist  Streams  \
# 0                      Louco       Piruka   273104
# 1               Dance Monkey  Tones And I   241243
# 2          Hoji N'ka ta Rola  Julinho Ksd   209372
# 3               menina solta    Giulia Be   201290
# 4  Essa Saia (feat. Ivandro)        Bispo   194053
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/5RPewmKIUL2vWtQ...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/3EtXiDhRO8psTWs...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/2MOq63fxuFLYQM3...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/2OI0z4fQD8NQPfY...   12/27/19   1/3/20
#
#      Region                     URI Danceability Energy Loudness Acousticness  \
# 0  Portugal  5RPewmKIUL2vWtQLI0Qp1F        0.727   0.51   -6.706        0.492
# ...

# %% [markdown]
# ## Spain

# %%
# Adding new columns to Spain DataFrame for song attributes
spain["URI"] = ""
spain["Danceability"] = ""
spain["Energy"] = ""
spain["Loudness"] = ""
spain["Acousticness"] = ""
spain["Instrumentalness"] = ""
spain["Liveness"] = ""
spain["Valence"] = ""
spain["Tempo"] = ""
spain["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(spain)

# %%
spain.head()
# Out:
#                Track Name       Artist  Streams  \
# 0                    Tusa      KAROL G  3262049
# 1  Alocao (With Bad Gyal)  Omar Montes  2292052
# 2            Dance Monkey  Tones And I  2077853
# 3                     "+"       Aitana  1946339
# 4                   Zorra     Bad Gyal  1786898
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/7k4t7uLgtOxPwTp...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/6RyuoOJXNzlVWpf...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/5Cbo7oz78gqkzV3...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/0OP1RzrglC008kj...   12/27/19   1/3/20
#
#   Region                     URI Danceability Energy Loudness Acousticness  \
# 0  Spain  7k4t7uLgtOxPwTpFmtJNTY        0.803  0.715    -3.28        0.295
# 1  Spain  6RyuoOJXNzlVWpfC5xQyeI        0.673  0.752   -4.705        0.214
# ...

# %% [markdown]
# ## Switzerland

# %%
# Adding new columns to Switzerland DataFrame for song attributes
switzerland["URI"] = ""
switzerland["Danceability"] = ""
switzerland["Energy"] = ""
switzerland["Loudness"] = ""
switzerland["Acousticness"] = ""
switzerland["Instrumentalness"] = ""
switzerland["Liveness"] = ""
switzerland["Valence"] = ""
switzerland["Tempo"] = ""
switzerland["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(switzerland)

# %%
switzerland.head()
# Out:
#      Track Name          Artist  Streams  \
# 0  Dance Monkey     Tones And I   387914
# 1        Roller      Apache 207   208579
# 2       ROXANNE  Arizona Zervas   186444
# 3       Falling   Trevor Daniel   175728
# 4      Memories        Maroon 5   159600
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/6hw1Sy9wZ8UCxYG...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/696DnlkuDOXcMAn...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/4TnjEaWOeW0eKTK...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/2b8fOow8UzyDFAE...   12/27/19   1/3/20
#
#         Region                     URI Danceability Energy Loudness  \
# 0  Switzerland  1rgnBhdG2JDFTbYkYRZAku        0.825  0.593   -6.401
# 1  Switzerland  6hw1Sy9wZ8UCxYGdpKrU6M        0.941  0.758    -6.47
# ...

# %% [markdown]
# ## Taiwan

# %%
# Adding new columns to Taiwan DataFrame for song attributes
taiwan["URI"] = ""
taiwan["Danceability"] = ""
taiwan["Energy"] = ""
taiwan["Loudness"] = ""
taiwan["Acousticness"] = ""
taiwan["Instrumentalness"] = ""
taiwan["Liveness"] = ""
taiwan["Valence"] = ""
taiwan["Tempo"] = ""
taiwan["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(taiwan)

# %%
taiwan.head()
# Out:
#      Track Name         Artist  Streams  \
# 0   Without You  é«˜çˆ¾å®£ OSN   290652
# 1        å¥è™Ÿ         G.E.M.   252127
# 2        Psycho     Red Velvet   228274
# 3  èªªå¥½ä¸å“­       Jay Chou   209623
# 4     SeÃ±orita   Shawn Mendes   208536
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/0KWnRv3wxjltYVB...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/66YKSygcUZHHqHJ...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/3CYH422oy1cZNoo...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/56wVfJKtnwlSZtC...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/6v3KW9xbzN5yKLt...   12/27/19   1/3/20
#
#    Region                     URI Danceability Energy Loudness Acousticness  \
# 0  Taiwan  0KWnRv3wxjltYVB3MqjNd2        0.669  0.698   -4.613        0.571
# 1  Taiwan  66YKSygcUZHHqHJZcWslI3         0.72   0.48   -8.552        0.248
# ...

# %% [markdown]
# ## United Kingdom

# %%
# Adding new columns to United Kingdom DataFrame for song attributes
uk["URI"] = ""
uk["Danceability"] = ""
uk["Energy"] = ""
uk["Loudness"] = ""
uk["Acousticness"] = ""
uk["Instrumentalness"] = ""
uk["Liveness"] = ""
uk["Valence"] = ""
uk["Tempo"] = ""
uk["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(uk)

# %%
uk.head()
# Out:
#                               Track Name          Artist  Streams  \
# 0                           Dance Monkey     Tones And I  3247913
# 1  Own It (feat. Ed Sheeran & Burna Boy)         Stormzy  2779032
# 2                                ROXANNE  Arizona Zervas  2677018
# 3                        Don't Start Now        Dua Lipa  2181098
# 4                          Before You Go   Lewis Capaldi  2180091
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/4QPEwDdOMhY7rNS...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/696DnlkuDOXcMAn...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/6WrI0LAC5M1Rw2M...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/2gMXnyrvIjhVBUZ...   12/27/19   1/3/20
#
#            Region                     URI Danceability Energy Loudness  \
# ...

# %% [markdown]
# ## United States

# %%
# Adding new columns to United States DataFrame for song attributes
usa["URI"] = ""
usa["Danceability"] = ""
usa["Energy"] = ""
usa["Loudness"] = ""
usa["Acousticness"] = ""
usa["Instrumentalness"] = ""
usa["Liveness"] = ""
usa["Valence"] = ""
usa["Tempo"] = ""
usa["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(usa)

# %%
usa.head()
# Out:
#   Track Name          Artist   Streams  \
# 0    The Box     Roddy Ricch  12533419
# 1    ROXANNE  Arizona Zervas   9844160
# 2    Circles     Post Malone   7932216
# 3        BOP          DaBaby   7560429
# 4    Falling   Trevor Daniel   7197448
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/0nbXyq5TXYPCO7p...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/696DnlkuDOXcMAn...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/21jGcNKet2qwijl...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/6Ozh9Ok6h4Oi1wU...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/4TnjEaWOeW0eKTK...   12/27/19   1/3/20
#
#           Region                     URI Danceability Energy Loudness  \
# 0  United States  0nbXyq5TXYPCO7pr3N8S4I        0.896  0.586   -6.687
# 1  United States  696DnlkuDOXcMAnKlTgXXK        0.621  0.601   -5.616
# 2  United States  21jGcNKet2qwijlDFuPiPb        0.695  0.762   -3.497
# ...

# %%
usa.to_csv("united_states_with_song_stats.csv", index=False)

# %% [markdown]
# ## Vietnam

# %%
# Adding new columns to Vietnam DataFrame for song attributes
vietnam["URI"] = ""
vietnam["Danceability"] = ""
vietnam["Energy"] = ""
vietnam["Loudness"] = ""
vietnam["Acousticness"] = ""
vietnam["Instrumentalness"] = ""
vietnam["Liveness"] = ""
vietnam["Valence"] = ""
vietnam["Tempo"] = ""
vietnam["Duration_Ms"] = ""

# %%
add_stats_to_existing_dataframe(vietnam)

# %%
vietnam.head()
# Out:
#                          Track Name               Artist  Streams  \
# 0                            Psycho           Red Velvet   205528
# 1  CÃ³ ChÃ ng Trai Viáº¿t LÃªn CÃ¢y  Phan Máº¡nh Quá»³nh   170410
# 2                      Dance Monkey          Tones And I   143157
# 3                       Lá»‘i Nhá»                 Äen   135681
# 4                         SeÃ±orita         Shawn Mendes   127226
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/3CYH422oy1cZNoo...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/1U8bwOTAtnqlWMC...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/22F7P7QnaVspdf5...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/6v3KW9xbzN5yKLt...   12/27/19   1/3/20
#
#     Region                     URI Danceability Energy Loudness Acousticness  \
# ...

# %% [markdown]
# ## Export

# %%
italy.to_csv("italy_with_song_stats.csv", index=False)

# %%
# Exporting all DataFrames to CSV
france.to_csv("france_with_song_stats.csv", index=False)
italy.to_csv("italy_with_song_stats.csv", index=False)
portugal.to_csv("portugal_with_song_stats.csv", index=False)
spain.to_csv("spain_with_song_stats.csv", index=False)
switzerland.to_csv("switzerland_with_song_stats.csv", index=False)
taiwan.to_csv("taiwan_with_song_stats.csv", index=False)
uk.to_csv("united_kingdom_with_song_stats.csv", index=False)
usa.to_csv("united_states_with_song_stats.csv", index=False)
vietnam.to_csv("vietnam_with_song_stats.csv", index=False)

# %% [markdown]
# # Combine COVID lockdown data with existing song data
# Creating a master DataFrame with all information needed for analysis

# %%
italy1 = pandas.read_csv("italy_with_song_stats.csv")
france1 = pandas.read_csv("france_with_song_stats.csv")
portugal1 = pandas.read_csv("portugal_with_song_stats.csv")
spain1 = pandas.read_csv("spain_with_song_stats.csv")
switzerland1 = pandas.read_csv("switzerland_with_song_stats.csv")
taiwan1 = pandas.read_csv("taiwan_with_song_stats.csv")
uk1 = pandas.read_csv("united_kingdom_with_song_stats.csv")
us1 = pandas.read_csv("united_states_with_song_stats.csv")
vietnam1 = pandas.read_csv("vietnam_with_song_stats.csv")

# %%
us1 = pandas.read_csv("united_states_with_song_stats.csv")
us1["Current Lockdown"] = ""

# %%
italy1["Current Lockdown"] = ""
france1["Current Lockdown"] = ""
portugal1["Current Lockdown"] = ""
spain1["Current Lockdown"] = ""
switzerland1["Current Lockdown"] = ""
taiwan1["Current Lockdown"] = ""
uk1["Current Lockdown"] = ""
us1["Current Lockdown"] = ""
vietnam1["Current Lockdown"] = ""

# %% [markdown]
# ### Italy Lockdown dates: 3/9/2020 - Present

# %%
italy1
# Out:
#                                              Track Name         Artist  \
# 0                                     blun7 a swishland    tha Supreme
# 1                                               fuck 3x    tha Supreme
# 2                                          Dance Monkey    Tones And I
# 3          Ti volevo dedicare (feat. J-AX & Boomdabash)     Rocco Hunt
# 4     SUPREME - L'ego (feat. tha Supreme & Sfera Ebb...      Marracash
# ...                                                 ...            ...
# 1695                                         goosebumps   Travis Scott
# 1696                                     Il tuo profumo  Fred De Palma
# 1697                                         Ostia Lido           J-AX
# 1698                                    Mambo Salentino     Boomdabash
# 1699                          Margarita (con Marracash)         Elodie
#
#       Streams                                                URL Week Start  \
# ...

# %%
#seperating lock down vs no lockdown dates based on week start
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20"]

lock_down = ["2/28/20", "3/6/20", "3/13/20", "3/20/20",
"3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    italy1.loc[(italy1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    italy1.loc[(italy1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
italy1
# Out:
#                                              Track Name         Artist  \
# 0                                     blun7 a swishland    tha Supreme
# 1                                               fuck 3x    tha Supreme
# 2                                          Dance Monkey    Tones And I
# 3          Ti volevo dedicare (feat. J-AX & Boomdabash)     Rocco Hunt
# 4     SUPREME - L'ego (feat. tha Supreme & Sfera Ebb...      Marracash
# ...                                                 ...            ...
# 1695                                         goosebumps   Travis Scott
# 1696                                     Il tuo profumo  Fred De Palma
# 1697                                         Ostia Lido           J-AX
# 1698                                    Mambo Salentino     Boomdabash
# 1699                          Margarita (con Marracash)         Elodie
#
#       Streams                                                URL Week Start  \
# ...

# %%
italy1[italy1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### France Lockdown Dates: 3/17/20 - 5/11/20

# %%
#seperating lockdown vs no lockdown dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20"]

lock_down = [ "3/13/20", "3/20/20",
"3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    france1.loc[(france1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    france1.loc[(france1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
france1
# Out:
#            Track Name               Artist  Streams  \
# 0      Ne reviens pas               Gradur  3948207
# 1             Moulaga     Heuss L'enfoirÃ©  3035799
# 2        Dance Monkey          Tones And I  2282643
# 3     Blinding Lights           The Weeknd  1772905
# 4             Popopop                Gambi  1659801
# ...               ...                  ...      ...
# 1695           Savage  Megan Thee Stallion   382906
# 1696    Before You Go        Lewis Capaldi   382690
# 1697         MAMACITA      Black Eyed Peas   382529
# 1698      Breaking Me                Topic   374398
# 1699        Trop beau              Lomepal   369758
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/4TnFANpjVwVKWzk...   12/27/19   1/3/20
# 1     https://open.spotify.com/track/5BfCoUcWNXcpyJf...   12/27/19   1/3/20
# 2     https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# ...

# %%
france1[france1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### US Lockdown Dates: 3/17/20 - 5/31/20

# %%
#seperating lockdown periods dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20"]

lock_down = [ "3/13/20", "3/20/20",
"3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    us1.loc[(us1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    us1.loc[(us1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
us1.iloc[:,0:20].to_csv("united_states_with_song_stats.csv", index=False)

# %%
us1
# Out:
#            Track Name          Artist   Streams  \
# 0             The Box     Roddy Ricch  12533419
# 1             ROXANNE  Arizona Zervas   9844160
# 2             Circles     Post Malone   7932216
# 3                 BOP          DaBaby   7560429
# 4             Falling   Trevor Daniel   7197448
# ...               ...             ...       ...
# 1695       BELIEVE IT   PARTYNEXTDOOR   2097175
# 1696     One Man Band    Old Dominion   2096270
# 1697  Beautiful Crazy      Luke Combs   2093091
# 1698             Suge          DaBaby   2071727
# 1699   Sick and Tired       iann dior   2069669
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/0nbXyq5TXYPCO7p...   12/27/19   1/3/20
# 1     https://open.spotify.com/track/696DnlkuDOXcMAn...   12/27/19   1/3/20
# 2     https://open.spotify.com/track/21jGcNKet2qwijl...   12/27/19   1/3/20
# 3     https://open.spotify.com/track/6Ozh9Ok6h4Oi1wU...   12/27/19   1/3/20
# ...

# %%
us1[us1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### UK Lockdown Dates: 3/24/20 - 5/7/20

# %%
#seperating dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20","3/13/20"]

lock_down = ["3/20/20",
"3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    uk1.loc[(uk1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    uk1.loc[(uk1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
uk1
# Out:
#                                  Track Name            Artist  Streams  \
# 0                              Dance Monkey       Tones And I  3247913
# 1     Own It (feat. Ed Sheeran & Burna Boy)           Stormzy  2779032
# 2                                   ROXANNE    Arizona Zervas  2677018
# 3                           Don't Start Now          Dua Lipa  2181098
# 4                             Before You Go     Lewis Capaldi  2180091
# ...                                     ...               ...      ...
# 1695   ily (i love you baby) (feat. Emilee)         Surf Mesa   491170
# 1696                             SICKO MODE      Travis Scott   490965
# 1697                     Head in the Clouds    Gerry Cinnamon   489951
# 1698            Strike a Pose (feat. Aitch)  Young T & Bugsey   488490
# 1699                  when the party's over     Billie Eilish   473821
#
#                                                     URL Week Start Week End  \
# ...

# %%
uk1[uk1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### Portugal Lockdown Dates: 3/19/20 - 5/4/20

# %%
#seperating dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20","3/13/20","3/20/20"]

lock_down = ["3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values

for date in no_lockdowns: 
    portugal1.loc[(portugal1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    portugal1.loc[(portugal1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
portugal1
# Out:
#                       Track Name          Artist  Streams  \
# 0                          Louco          Piruka   273104
# 1                   Dance Monkey     Tones And I   241243
# 2              Hoji N'ka ta Rola     Julinho Ksd   209372
# 3                   menina solta       Giulia Be   201290
# 4      Essa Saia (feat. Ivandro)           Bispo   194053
# ...                          ...             ...      ...
# 1695                 FIND MY WAY          DaBaby    45848
# 1696                      Bolero         X-Tense    45430
# 1697                     Shallow       Lady Gaga    45177
# 1698  Surtada - Remix Brega Funk  DadÃ¡ BoladÃ£o    44753
# 1699                ImpossÃ­veis          Piruka    44688
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/5RPewmKIUL2vWtQ...   12/27/19   1/3/20
# 1     https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# ...

# %%
#checking all rows have been set
portugal1[portugal1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### Spain Lockdown Dates: 3/14/20 - 5/9/20

# %%
#seperating dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20"]

lock_down = ["3/13/20","3/20/20","3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    spain1.loc[(spain1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    spain1.loc[(spain1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
spain1
# Out:
#                   Track Name        Artist  Streams  \
# 0                       Tusa       KAROL G  3262049
# 1     Alocao (With Bad Gyal)   Omar Montes  2292052
# 2               Dance Monkey   Tones And I  2077853
# 3                        "+"        Aitana  1946339
# 4                      Zorra      Bad Gyal  1786898
# ...                      ...           ...      ...
# 1695           Sigues Con El  DÃ­melo Flow   370831
# 1696                Callaita     Bad Bunny   370775
# 1697            Easy - Remix   Jhay Cortez   361477
# 1698                Memories      Maroon 5   361118
# 1699               SeÃ±orita  Shawn Mendes   359556
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/7k4t7uLgtOxPwTp...   12/27/19   1/3/20
# 1     https://open.spotify.com/track/6RyuoOJXNzlVWpf...   12/27/19   1/3/20
# 2     https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# ...

# %%
#checking that all values have been set
spain1[spain1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### Switzerland Lockdown Dates: 3/17/20 - 5/11/20

# %%
#seperating dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20"]

lock_down = ["3/13/20","3/20/20","3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    switzerland1.loc[(switzerland1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    switzerland1.loc[(switzerland1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
switzerland1
# Out:
#                              Track Name             Artist  Streams  \
# 0                          Dance Monkey        Tones And I   387914
# 1                                Roller         Apache 207   208579
# 2                               ROXANNE     Arizona Zervas   186444
# 3                               Falling      Trevor Daniel   175728
# 4                              Memories           Maroon 5   159600
# ...                                 ...                ...      ...
# 1695                What A Man Gotta Do     Jonas Brothers    55043
# 1696  I Don't Care (with Justin Bieber)         Ed Sheeran    54889
# 1697                             Jolina              Samra    53807
# 1698                          Rescue Me        OneRepublic    53637
# 1699                   Level of Concern  Twenty One Pilots    53178
#
#                                                     URL Week Start Week End  \
# ...

# %%
#checking all values have been set
switzerland1[switzerland1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### Taiwan Lockdown Dates: No lockdown

# %%
taiwan1["Current Lockdown"]="No"

# %%
taiwan1
# Out:
#                        Track Name         Artist  Streams  \
# 0                     Without You  é«˜çˆ¾å®£ OSN   290652
# 1                          å¥è™Ÿ         G.E.M.   252127
# 2                          Psycho     Red Velvet   228274
# 3                    èªªå¥½ä¸å“­       Jay Chou   209623
# 4                       SeÃ±orita   Shawn Mendes   208536
# ...                           ...            ...      ...
# 1695                 å¤©çœŸæœ‰é‚ª       Yoga Lin    63991
# 1696                  Sweet Night              V    62684
# 1697  Midnight (feat. Liam Payne)         Alesso    62655
# 1698                  Sunday Best       Surfaces    61765
# 1699                Am I Who I Am     Vicky Chen    60918
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/0KWnRv3wxjltYVB...   12/27/19   1/3/20
# 1     https://open.spotify.com/track/66YKSygcUZHHqHJ...   12/27/19   1/3/20
# ...

# %%
taiwan1[taiwan1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %% [markdown]
# ### Vietnam Lockdown Dates: 3/31/20 - 4/22/20

# %%
#seperating dates
no_lockdowns = ["12/27/19","1/3/20", "1/10/20", "1/17/20",
"1/24/20", "1/31/20", "2/7/20", "2/14/20","2/21/20","2/28/20", "3/6/20","3/13/20","3/20/20"]

lock_down = ["3/27/20", "4/3/20","4/10/20","4/17/20"]

#setting Current Lockdown column values
for date in no_lockdowns: 
    vietnam1.loc[(vietnam1["Week Start"]== date),"Current Lockdown"]="No"

for date in lock_down: 
    vietnam1.loc[(vietnam1["Week Start"]== date),"Current Lockdown"]="Yes"

# %%
vietnam1
# Out:
#                              Track Name               Artist  Streams  \
# 0                                Psycho           Red Velvet   205528
# 1      CÃ³ ChÃ ng Trai Viáº¿t LÃªn CÃ¢y  Phan Máº¡nh Quá»³nh   170410
# 2                          Dance Monkey          Tones And I   143157
# 3                           Lá»‘i Nhá»                 Äen   135681
# 4                             SeÃ±orita         Shawn Mendes   127226
# ...                                 ...                  ...      ...
# 1695                  Louder than bombs                  BTS    29963
# 1696                           Any song                 ZICO    29859
# 1697         Buá»“n ThÃ¬ Cá»© KhÃ³c Äi             Lynk Lee    29856
# 1698  10,000 Hours (with Justin Bieber)           Dan + Shay    29656
# 1699                       Ná»¥ CÆ°á»i            Rhymastic    29530
#
#                                                     URL Week Start Week End  \
# ...

# %%
vietnam1[vietnam1['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %%
all = [france1,italy1,portugal1,spain1,switzerland1,taiwan1,uk1,us1,vietnam1]

# %%
#combining all individual country frames into single frame
master_frame = pandas.concat(all)

# %%
master_frame
# Out:
#                              Track Name            Artist  Streams  \
# 0                        Ne reviens pas            Gradur  3948207
# 1                               Moulaga  Heuss L'enfoirÃ©  3035799
# 2                          Dance Monkey       Tones And I  2282643
# 3                       Blinding Lights        The Weeknd  1772905
# 4                               Popopop             Gambi  1659801
# ...                                 ...               ...      ...
# 1695                  Louder than bombs               BTS    29963
# 1696                           Any song              ZICO    29859
# 1697         Buá»“n ThÃ¬ Cá»© KhÃ³c Äi          Lynk Lee    29856
# 1698  10,000 Hours (with Justin Bieber)        Dan + Shay    29656
# 1699                       Ná»¥ CÆ°á»i         Rhymastic    29530
#
#                                                     URL Week Start Week End  \
# 0     https://open.spotify.com/track/4TnFANpjVwVKWzk...   12/27/19   1/3/20
# ...

# %%
#checking for mistakes
master_frame[master_frame['Current Lockdown'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Streams, URL, Week Start, Week End, Region, URI, Danceability, Energy, Loudness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_Ms, Current Lockdown]
# Index: []

# %%
master_frame[master_frame["Region"]=="Vietnam"]
# Out:
#                              Track Name               Artist  Streams  \
# 0                                Psycho           Red Velvet   205528
# 1      CÃ³ ChÃ ng Trai Viáº¿t LÃªn CÃ¢y  Phan Máº¡nh Quá»³nh   170410
# 2                          Dance Monkey          Tones And I   143157
# 3                           Lá»‘i Nhá»                 Äen   135681
# 4                             SeÃ±orita         Shawn Mendes   127226
# ...                                 ...                  ...      ...
# 1695                  Louder than bombs                  BTS    29963
# 1696                           Any song                 ZICO    29859
# 1697         Buá»“n ThÃ¬ Cá»© KhÃ³c Äi             Lynk Lee    29856
# 1698  10,000 Hours (with Justin Bieber)           Dan + Shay    29656
# 1699                       Ná»¥ CÆ°á»i            Rhymastic    29530
#
#                                                     URL Week Start Week End  \
# ...

# %%
#export to csv
master_frame.to_csv("master_frame.csv", index=False)

# %%
master_frame.head()
# Out:
#         Track Name            Artist  Streams  \
# 0   Ne reviens pas            Gradur  3948207
# 1          Moulaga  Heuss L'enfoirÃ©  3035799
# 2     Dance Monkey       Tones And I  2282643
# 3  Blinding Lights        The Weeknd  1772905
# 4          Popopop             Gambi  1659801
#
#                                                  URL Week Start Week End  \
# 0  https://open.spotify.com/track/4TnFANpjVwVKWzk...   12/27/19   1/3/20
# 1  https://open.spotify.com/track/5BfCoUcWNXcpyJf...   12/27/19   1/3/20
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...   12/27/19   1/3/20
# 3  https://open.spotify.com/track/0sf12qNH5qcw8qp...   12/27/19   1/3/20
# 4  https://open.spotify.com/track/18HNGxDOcshRU2H...   12/27/19   1/3/20
#
#    Region                     URI  Danceability  Energy  Loudness  \
# 0  France  4TnFANpjVwVKWzkxNzIyFH         0.932   0.778    -3.384
# 1  France  5BfCoUcWNXcpyJfjXRIeyC         0.710   0.699    -4.664
# ...

# %% [markdown]
# ## Potential Problems with Our Dataset
#
# - Since lockdowns are by state/province, we mark a region as under lockdown so long as one state/province within the entire region is still under lockdown. This may lead to some inaccuracies in our analysis in a large country such as the United States, where the lockdown status of an epicenter like New York City may not be reflective of the status of the entire nation. However, because Spotify song data is only available by country and not smaller provinces, we had to make these assumptions and aggregate the COVID-19 data in terms of countries to match how the Spotify data was collected.
# - Spotify charts of top songs are collected on a weekly basis; however, some countries' lockdowns started in the middle of the week. Therefore, there may be slight inconsistencies in our data.
# - Spotify top song chart data may be a more accurate reflection of true music tastes and trends in countries that have a larger proportion of Spotify users. For example, in a country like the United States with a greater number of Spotify listeners than Vietnam, the song charts may be a more accurate reflection of true song trends than the song charts of Vietnam.

# %% [markdown]
# **Notes:**
#
# Please see final report notebook for data descriptions draft :)
#
# Data can be found in master_frame.csv , raw data & data after processing steps in data folder
